# %%
import serial
import paho.mqtt.client as mqtt
import re

# %%
SER_PORT = "/dev/cu.usbmodem14203"
GROUP_NAME = "dua_lipas"
MY_NAME = "stacey"
BROKER_URL = "test.mosquitto.org"
BROKER_PORT = 1883

MESSAGE_RE = b"[PR][0-8][0-9A-B]"
PUB_TOPIC = "IC.embedded/" + GROUP_NAME + "/synth/" + MY_NAME
SUB_TOPIC = "IC.embedded/" + GROUP_NAME + "/synth" + '/+'

# %%
#Callback for incoming MQTT messages
def on_message(client, userdata, msg):
    pub_name = msg.topic.split('/')[-1]
    match = re.match(MESSAGE_RE,msg.payload)
    if match:
        if pub_name != MY_NAME:
            ser.write(msg.payload+b'\n')
            print("In from {}: {}".format(pub_name,str(match.group(0),'ascii')))
    else:
        print("Syntax Error in message from {}: {}".format(pub_name,msg.payload))

# %%
#Initialise serial
try:
    ser = serial.Serial(SER_PORT, 115200, timeout=1)
except:
    print("Could not open serial port")
#     quit()

# %%
#Connect to broker
client = mqtt.Client()
try:
    client.connect(BROKER_URL, BROKER_PORT, 60)
except:
    print("Couldn't connect to broker")
    ser.close()
    quit()
client.subscribe(SUB_TOPIC)
client.on_message = on_message
client.loop_start()

# %%
#Wait for messages on serial port
try:
    while(True):
        line = ser.readline()
        if line:
            match = re.match(MESSAGE_RE,line)
            if match:
                client.publish(PUB_TOPIC,match.group(0))
                print("Out: "+str(match.group(0),'ascii'))
            else:
                print("Syntax Error in message from synth: "+str(line,'ascii'),end='')
except KeyboardInterrupt:
    ser.close()
    client.disconnect()
except:
    ser.close()
    client.disconnect()
    raise
# Out:
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: R4B
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: R4B
# Out: P44
# Out: R44
# Out: P42
# Out: R42
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: R4B
# Out: P44
# Out: R44
# Out: P42
# Out: R42
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: R4B
# Out: P44
# Out: R44
# Out: P42
# Out: R42
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: P49
# Out: R4B
# Out: P47
# Out: R49
# Out: R47
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: R4B
# Out: P49
# Out: R49
# Out: P47
# Out: R47
# In from barbara: P80
# In from barbara: R80
# In from barbara: P84
# In from barbara: R84
# In from barbara: P87
# In from barbara: R87
# In from barbara: P85
# In from barbara: R85
# In from barbara: P84
# In from barbara: R84
# In from barbara: P82
# In from barbara: R82
# In from barbara: P52
# In from barbara: R52
# In from barbara: P57
# In from barbara: R57
# In from barbara: P44
# In from barbara: R44
# Out: P44
# Out: R44
# Out: P47
# Out: R47
# Out: P4B
# Out: R4B
# Out: P44
# Out: P45
# Out: R45
# Out: R44
# Out: P42
# Out: R42
# In from barbara: P4B
# In from barbara: R4B
# Out: P42
# Out: R42
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R44
# In from barbara: R47
# In from barbara: R40
# Out: P54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: R54
# Out: P57
# Out: R57
# Out: P5B
# Out: R5B
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P54
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: R54
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# Out: P52
# In from barbara: P44
# In from barbara: P4B
# In from barbara: P47
# Out: R52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# Out: P57
# Out: R57
# Out: P5B
# In from barbara: R40
# Out: R5B
# In from barbara: R44
# In from barbara: R47
# Out: P54
# In from barbara: P49
# In from barbara: P42
# Out: R54
# In from barbara: R42
# In from barbara: R49
# In from barbara: P44
# In from barbara: P4B
# In from barbara: P47
# Out: P52
# In from barbara: R44
# In from barbara: R4B
# In from barbara: R47
# Out: R52
# Out: P54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: R54
# Out: P57
# Out: R57
# Out: P5B
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# Out: P54
# In from barbara: P49
# In from barbara: P42
# In from barbara: P46
# In from barbara: R49
# In from barbara: R42
# In from barbara: R46
# Out: R54
# In from barbara: P47
# In from barbara: P4B
# In from barbara: P44
# Out: P52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: R52
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: P54
# Out: R54
# Out: P57
# In from barbara: R47
# In from barbara: R40
# In from barbara: R44
# Out: R57
# Out: P5B
# Out: R5B
# Out: P54
# Out: R54
# Out: P52
# Out: R52
# Out: P50
# Out: P57
# Out: P54
# Out: R50
# Out: R54
# Out: R57
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: R49
# In from barbara: R42
# Out: P50
# Out: R50
# In from barbara: P4B
# In from barbara: P47
# In from barbara: P44
# Out: P50
# Out: P54
# In from barbara: R4B
# In from barbara: R47
# In from barbara: R44
# Out: P57
# Out: R50
# Out: R54
# Out: R57
# Out: P52
# Out: P59
# Out: P55
# Out: R59
# Out: R52
# Out: R55
# Out: P54
# Out: P57
# Out: P5B
# Out: R5B
# Out: R54
# Out: R57
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P46
# In from barbara: P49
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: R42
# In from barbara: R49
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R47
# In from barbara: R4B
# In from barbara: R44
# In from barbara: P47
# In from barbara: P40
# In from barbara: P44
# In from barbara: R47
# In from barbara: R40
# In from barbara: R44
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# In from barbara: R49
# In from barbara: R46
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R47
# In from barbara: R42
# In from barbara: R4B
# In from barbara: P4B
# In from barbara: P44
# In from barbara: P47
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R42
# In from barbara: R4B
# In from barbara: R47
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# Out: P57
# In from barbara: R40
# Out: R57
# In from barbara: R47
# In from barbara: R44
# Out: P5B
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: R5B
# In from barbara: R46
# In from barbara: R42
# In from barbara: R49
# Out: P54
# In from barbara: P47
# In from barbara: P4B
# In from barbara: P44
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: P52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R40
# Out: R52
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R44
# In from barbara: R40
# In from barbara: R47
# In from barbara: P44
# In from barbara: R44
# Out: P54
# Out: R54
# Out: P57
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R40
# Out: R57
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# In from barbara: P42
# Out: R5B
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# Out: P54
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# Out: R54
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P40
# Out: P52
# In from barbara: P47
# In from barbara: P44
# Out: R52
# Out: P54
# Out: R54
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P57
# In from barbara: P42
# In from barbara: P46
# In from barbara: P49
# In from barbara: R49
# In from barbara: R42
# In from barbara: R46
# Out: R57
# In from barbara: P4B
# In from barbara: P44
# In from barbara: P47
# Out: P5B
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: R5B
# In from barbara: P47
# Out: P54
# In from barbara: P40
# In from barbara: P44
# Out: R54
# Out: P52
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: R52
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# In from barbara: P4B
# In from barbara: P44
# In from barbara: P47
# Out: P54
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P40
# Out: R54
# In from barbara: P44
# In from barbara: P47
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R47
# In from barbara: R44
# Out: P5B
# In from barbara: P47
# Out: R5B
# In from barbara: P4B
# In from barbara: P44
# In from barbara: R47
# Out: P54
# In from barbara: R44
# In from barbara: R4B
# In from barbara: P4B
# In from barbara: P42
# In from barbara: P47
# Out: R54
# In from barbara: R42
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P44
# In from barbara: P49
# Out: P52
# In from barbara: R44
# In from barbara: R49
# Out: R52
# Out: P54
# Out: R54
# Out: P57
# Out: R57
# Out: P54
# Out: R54
# Out: P57
# Out: R57
# Out: P5B
# Out: R5B
# Out: P54
# Out: R54
# Out: P52
# Out: R52
# Out: P54
# Out: R54
# Out: P57
# Out: R57
# Out: P5B
# Out: R5B
# Out: P54
# Out: R54
# Out: P52
# Out: R52
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# Out: P57
# Out: R57
# In from barbara: R44
# In from barbara: R40
# Out: P5B
# In from barbara: R47
# Out: R5B
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: P54
# Out: R54
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# In from barbara: P47
# In from barbara: P4B
# In from barbara: P44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: R44
# In from barbara: P40
# In from barbara: P47
# In from barbara: R40
# In from barbara: R47
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# Out: P54
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# Out: R54
# In from barbara: R46
# In from barbara: R49
# In from barbara: P44
# Out: P52
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: R52
# Out: P54
# In from barbara: P40
# In from barbara: P47
# Out: R54
# In from barbara: P44
# Out: P57
# Out: R57
# Out: P5B
# Out: R5B
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P49
# Out: P54
# In from barbara: P42
# In from barbara: P46
# Out: R54
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# In from barbara: P4B
# Out: P52
# In from barbara: P44
# In from barbara: P47
# Out: R52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# Out: R54
# In from barbara: P40
# Out: P57
# In from barbara: P44
# In from barbara: P47
# Out: R57
# In from barbara: R40
# Out: P5B
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# In from barbara: P42
# Out: P54
# In from barbara: P49
# In from barbara: R49
# Out: R54
# In from barbara: R42
# Out: P52
# In from barbara: P4B
# In from barbara: P47
# In from barbara: P44
# Out: R52
# In from barbara: R4B
# In from barbara: R44
# In from barbara: R47
# Out: P54
# Out: R54
# Out: P57
# Out: R57
# Out: P59
# Out: R59
# Out: P5B
# In from barbara: P47
# Out: R5B
# In from barbara: P4B
# In from barbara: P44
# In from barbara: R44
# In from barbara: R4B
# In from barbara: R47
# Out: P59
# Out: R59
# In from barbara: P42
# Out: P57
# In from barbara: P49
# In from barbara: P46
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R47
# In from barbara: R4B
# In from barbara: R42
# Out: R57
# In from barbara: P47
# In from barbara: P40
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P46
# In from barbara: P49
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R42
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# Out: P57
# Out: R57
# Out: P5B
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# In from barbara: P42
# In from barbara: P49
# Out: P54
# In from barbara: P46
# In from barbara: R46
# Out: R54
# In from barbara: R49
# In from barbara: R42
# Out: P52
# In from barbara: P4B
# In from barbara: P44
# In from barbara: P47
# Out: R52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# In from barbara: P47
# In from barbara: P40
# In from barbara: P44
# Out: R54
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# Out: P54
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# In from barbara: R46
# Out: R54
# In from barbara: R49
# Out: P52
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# Out: R52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# In from barbara: P40
# Out: R54
# In from barbara: P47
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R40
# Out: P5B
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# Out: P54
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: R54
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# In from barbara: P4B
# Out: P52
# In from barbara: P42
# In from barbara: P47
# In from barbara: R42
# Out: R52
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# In from barbara: P47
# In from barbara: P4B
# In from barbara: P44
# Out: R54
# Out: P57
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: R57
# Out: P5B
# Out: R5B
# Out: P59
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# Out: R59
# In from barbara: R49
# In from barbara: R46
# Out: P57
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R42
# In from barbara: R47
# In from barbara: R4B
# Out: R57
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R40
# Out: P5B
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# In from barbara: P42
# Out: P54
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# Out: R54
# In from barbara: R46
# In from barbara: R49
# In from barbara: P47
# Out: P52
# In from barbara: P4B
# In from barbara: P44
# Out: R52
# In from barbara: R4B
# In from barbara: R44
# In from barbara: R47
# Out: P54
# In from barbara: P47
# Out: R54
# In from barbara: P40
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R44
# In from barbara: R40
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: P54
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# Out: R54
# Out: P52
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# Out: R52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# In from barbara: P47
# In from barbara: P40
# In from barbara: P44
# Out: R54
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# Out: P54
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: R54
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# Out: P52
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# Out: R52
# In from barbara: R44
# In from barbara: R4B
# In from barbara: R47
# Out: P54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: R54
# Out: P57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: R57
# Out: P5B
# Out: R5B
# In from barbara: P42
# In from barbara: P49
# Out: P59
# In from barbara: P46
# In from barbara: R46
# In from barbara: P46
# In from barbara: R46
# In from barbara: R42
# Out: R59
# In from barbara: R49
# Out: P57
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R47
# In from barbara: R4B
# In from barbara: R42
# Out: R57
# Out: P54
# Out: R54
# Out: P57
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: R57
# In from barbara: R40
# Out: P5B
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# In from barbara: P49
# In from barbara: P42
# Out: P59
# In from barbara: P46
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# Out: R59
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R44
# In from barbara: R4B
# In from barbara: R47
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# In from barbara: R44
# In from barbara: R40
# In from barbara: R47
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R44
# In from barbara: R40
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: P54
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# Out: R54
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# Out: P52
# Out: R52
# In from barbara: R47
# In from barbara: R4B
# In from barbara: R44
# Out: P54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: R54
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# Out: P54
# In from barbara: P49
# In from barbara: P42
# In from barbara: P46
# In from barbara: R42
# Out: R54
# In from barbara: R49
# In from barbara: R46
# In from barbara: P44
# Out: P52
# In from barbara: P4B
# In from barbara: P47
# Out: R52
# In from barbara: R47
# In from barbara: R44
# In from barbara: R4B
# Out: P54
# In from barbara: P47
# Out: R54
# In from barbara: P40
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# Out: P5B
# In from barbara: R47
# Out: R5B
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# Out: P54
# In from barbara: R46
# In from barbara: R49
# Out: R54
# In from barbara: R42
# Out: P52
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# Out: R52
# In from barbara: R42
# In from barbara: R4B
# Out: P54
# In from barbara: R47
# In from barbara: P44
# Out: R54
# In from barbara: P47
# In from barbara: P4B
# Out: P57
# In from barbara: R4B
# Out: R57
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# Out: P59
# In from barbara: P49
# In from barbara: P46
# Out: R59
# In from barbara: R46
# In from barbara: R42
# In from barbara: R49
# Out: P57
# In from barbara: P42
# In from barbara: P4B
# In from barbara: P47
# In from barbara: R42
# Out: R57
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# In from barbara: R44
# In from barbara: R47
# In from barbara: R40
# Out: P50
# Out: P59
# Out: P54
# Out: R54
# Out: R50
# Out: R59
# In from barbara: P40
# In from barbara: P44
# In from barbara: P47
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# In from barbara: R46
# In from barbara: R49
# In from barbara: R42
# In from barbara: P44
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P47
# In from barbara: P40
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: R49
# In from barbara: R42
# In from barbara: P4B
# In from barbara: P47
# In from barbara: P44
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P47
# In from barbara: P40
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# In from barbara: R46
# In from barbara: R49
# In from barbara: P47
# In from barbara: P4B
# In from barbara: P44
# In from barbara: R4B
# In from barbara: R44
# In from barbara: R47
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# In from barbara: P42
# In from barbara: P49
# In from barbara: P46
# In from barbara: R42
# In from barbara: R49
# In from barbara: R46
# In from barbara: P49
# In from barbara: P42
# In from barbara: P46
# In from barbara: R46
# In from barbara: R42
# In from barbara: R49
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R42
# In from barbara: R47
# In from barbara: R4B
# In from barbara: P4B
# In from barbara: P47
# In from barbara: P44
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# Out: R54
# In from barbara: P40
# In from barbara: P47
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# In from barbara: P46
# In from barbara: P49
# Out: P54
# In from barbara: R46
# In from barbara: R49
# Out: R54
# In from barbara: R42
# In from barbara: P47
# Out: P52
# In from barbara: P44
# In from barbara: P4B
# Out: R52
# In from barbara: R44
# In from barbara: R4B
# In from barbara: R47
# Out: P54
# In from barbara: P40
# Out: R54
# Out: P57
# In from barbara: P44
# In from barbara: P47
# Out: R57
# In from barbara: R40
# Out: P5B
# In from barbara: R44
# In from barbara: R47
# Out: R5B
# In from barbara: P49
# In from barbara: P42
# Out: P54
# In from barbara: P46
# In from barbara: R46
# Out: R54
# In from barbara: R49
# In from barbara: R42
# Out: P52
# In from barbara: P4B
# In from barbara: P44
# In from barbara: P47
# Out: R52
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: P54
# In from barbara: P47
# Out: R54
# In from barbara: P40
# In from barbara: P44
# Out: P57
# Out: R57
# In from barbara: R40
# In from barbara: R44
# In from barbara: R47
# Out: P5B
# Out: R5B
# In from barbara: P42
# Out: P54
# In from barbara: P49
# In from barbara: P46
# In from barbara: R49
# In from barbara: R42
# In from barbara: R46
# Out: R54
# Out: P52
# In from barbara: P4B
# In from barbara: P42
# In from barbara: P47
# In from barbara: R4B
# Out: R52
# In from barbara: R47
# In from barbara: R42
# Out: P54
# In from barbara: P47
# In from barbara: P4B
# In from barbara: P44
# Out: R54
# Out: P57
# In from barbara: R44
# In from barbara: R47
# In from barbara: R4B
# Out: R57
# Out: P5B
# Out: R5B
# In from barbara: P49
# In from barbara: P42
# In from barbara: P46
# Out: P59
# Out: R59
# In from barbara: R46
# In from barbara: R42
# In from barbara: R49
# Out: P57
# In from barbara: P42
# In from barbara: P47
# In from barbara: P4B
# In from barbara: R4B
# In from barbara: R42
# In from barbara: R47
# Out: R57
# Syntax Error in message from synth: P5
# Out: R55
# Out: P57
# Out: P59
# Out: R57
# Out: R59
# In from barbara: P40
# In from barbara: R40
# In from barbara: P40
# In from barbara: R40
# Out: P50
# Out: R50
# Out: P50
# Out: R50
# Out: P54
# Out: R54
# Out: P50
# Out: R50
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/serial/serialposix.py in read(self, size)
#     574                     break   # timeout
# --> 575                 buf = os.read(self.fd, size - len(read))
#     576             except OSError as e:
#
# OSError: [Errno 6] Device not configured
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-6-aa69f52382c0> in <module>
#       2 try:
#       3     while(True):
# ----> 4         line = ser.readline()
#       5         if line:
#       6             match = re.match(MESSAGE_RE,line)
#
# ~/miniconda3/lib/python3.8/site-packages/serial/serialposix.py in read(self, size)
#     579                 # https://www.python.org/dev/peps/pep-0475.
#     580                 if e.errno not in (errno.EAGAIN, errno.EALREADY, errno.EWOULDBLOCK, errno.EINPROGRESS, errno.EINTR):
# --> 581                     raise SerialException('read failed: {}'.format(e))
#     582             except select.error as e:
#     583                 # this is for Python 2.x
#
# SerialException: read failed: [Errno 6] Device not configured
